# %%
import pybel
pybel.ipython_3d = True

# %%
mol = next(pybel.readfile("cif", "cif_files/CuBTC.cif"))

# %%
mol
# Out:
# <div id="molecule_214d1982-7576-4f4b-921d-b07ca10312fa"></div>
#                <script type="text/javascript">
#                requirejs.config({baseUrl: "/",
#                                  paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/openbabel/contributed/master/web/imolecule/build/imolecule.min']}});
#                require(['imolecule'], function () {
#                    var $d = $('#molecule_214d1982-7576-4f4b-921d-b07ca10312fa');
#                    $d.width(400); $d.height(300);
#                    $d.imolecule = jQuery.extend({}, imolecule);
#                    $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                             cameraType: 'perspective'});
# ...
